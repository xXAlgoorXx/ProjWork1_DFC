# %% [markdown]
# # Notebook to convert a Pytroch model to a HEF file

# %%
# import the ClientRunner class from the hailo_sdk_client package
from hailo_sdk_client import ClientRunner
import onnx
import sys
import os
import numpy as np
import torch
import clip
import open_clip
from pathlib import Path
from onnxsim import simplify
from PIL import Image

# Own modules
print(Path.cwd())
sys.path.append(str(Path.cwd().parent))
os.chdir(str(Path.cwd().parent))
import folderManagment.pathsToFolders as ptf #Controlls all paths #
# Out:
# /home/lukasschoepf/Documents/ProjWork1_DFC/python

# %% [markdown]
# Paths and names for models

# %%
chosen_hw_arch = "hailo8l"

har_path = ptf.HarPath
hef_path = ptf.Hefpath

# %% [markdown]
# ## Get ONNX file
#
# Diffrent for CLIP / TinyCLIP

# %% [markdown]
# For CLIP

# %%
model_name = "RN50x4"

device = "cuda" if torch.cuda.is_available() else "cpu" 
model, preprocess = clip.load(model_name, device=device)

vit = model.visual
input_pixels = model.visual.input_resolution
input_image = torch.rand(1, 3, input_pixels, input_pixels)

#input_image = preprocess(Image.open("hailoDFC/pics/car-967387_1280.png")).unsqueeze(0).to(device)
onnx_path = str(ptf.onnxFolder/ f"{model_name}.onnx")
print(f"Input: {input_pixels}")
vit.eval()
torch.onnx.export(vit,
            input_image,
            onnx_path,
            opset_version=14,
            do_constant_folding=True,)

# Simplify the ONNX model to resolve mismatches
simplified_model, check = simplify(onnx_path)
model_path_simple = f"hailoDFC/models/baseAndSimple/{model_name}_simple.onnx"

# Save the simplified model
onnx.save(simplified_model, model_path_simple)

print(f"Simple Model saved at {model_path_simple}")
# Out:
# Input: 288
# Simple Model saved at hailoDFC/models/baseAndSimple/RN50x4_simple.onnx

# %% [markdown]
# For TinyCLIP

# %%
model_name = "TinyCLIP-ResNet-19M-Text-19M" # TinyCLIP-ResNet-19M-Text-19M or TinyCLIP-ResNet-30M-Text-29M

device = "cuda" if torch.cuda.is_available() else "cpu" 
model, *_ = open_clip.create_model_and_transforms(model_name,pretrained=str(ptf.tinyClipModels / f"{model_name}-LAION400M.pt"))

vit = model.visual 
input_pixels = model.visual.image_size

print(f"Input: {input_pixels}")
input_image = torch.rand(1, 3, input_pixels, input_pixels)
# input_image = preprocess(Image.open("hailoDFC/pics/car-967387_1280.png")).unsqueeze(0).to(device)

onnx_path = str(ptf.onnxFolder/ f"{model_name}.onnx")
vit.eval()
torch.onnx.export(vit,
         input_image,
         onnx_path,
         opset_version=14,
         do_constant_folding=True,)

# Simplify the ONNX model to resolve mismatches
simplified_model, check = simplify(onnx_path)
model_name = "TinyRN"
model_path_simple = f"hailoDFC/models/{model_name}_simple.onnx"

# Save the simplified model
onnx.save(simplified_model, model_path_simple)

print(f"Simple Model saved at {model_path_simple}")
# Out:
# /home/lukasschoepf/Documents/ProjWork1_DFC/src/open_clip/factory.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=map_location)
# Input: 224
# Simple Model saved at hailoDFC/models/TinyRN_simple.onnx

# %% [markdown]
# Use model from Hailo

# %%
model_path_simple = "hailoDFC/models/modified/modified_RN50x4_simple.onnx"
model_name = "Modified_RN50x4"

# %% [markdown]
# ### Onnx to Har

# %%
runner = ClientRunner(hw_arch=chosen_hw_arch)


print(f"Take model from {model_path_simple}")
hn, npz = runner.translate_onnx_model(
    model_path_simple,
    model_name,
    start_node_names=["onnx::Cast_0"],
    disable_shape_inference= True,
    net_input_shapes=[1,3,288,288]
    # end_node_names=["/attnpool/MatMul_4"]
)

hailo_model_har_name = str(har_path / f"{model_name}_hailo_model.har")
runner.save_har(hailo_model_har_name)
# Out:
# Take model from hailoDFC/models/modified/modified_RN50x4_simple.onnx
# [info] Translation started on ONNX model Modified_RN50x4
# [info] Restored ONNX model Modified_RN50x4 (completion time: 00:00:00.53)
# [info] Extracted ONNXRuntime meta-data for Hailo model (completion time: 00:00:02.18)
# [info] Start nodes mapped from original model: 'onnx::Cast_0': 'Modified_RN50x4/input_layer1'.
# [info] End nodes mapped from original model: '/attnpool/MatMul_4'.
# [info] Unable to export parsing report: output
# [info] Translation completed on ONNX model Modified_RN50x4 (completion time: 00:00:02.41)
# [info] Saved HAR to: /home/lukasschoepf/Documents/ProjWork1_DFC/hailoDFC/models/Harfiles/Modified_RN50x4_hailo_model.har

# %% [markdown]
# ## Optimize Har file
#
# The next step is to optimze the har file. To do this we need a calibration dataset.

# %%
# preprocessing
from torchvision.transforms import Compose, Resize, CenterCrop, ToTensor, Normalize, PILToTensor
import os

try:
    from torchvision.transforms import InterpolationMode
    BICUBIC = InterpolationMode.BICUBIC
except ImportError:
    BICUBIC = Image.BICUBIC


datafolder = ptf.dataBaseFolder
input_folder = ptf.Dataset5Patch
calibFolder = datafolder / "calibData"

# %% [markdown]
# Functions to preprocess the input images to the right resolution

# %%
def _convert_image_to_rgb(image):
    return image.convert("RGB")

def transform(n_px):
    """
    n_px: input resolution of the network
    """
    return Compose([
        Resize(n_px, interpolation=BICUBIC),
        CenterCrop(n_px),
        _convert_image_to_rgb,
        ToTensor(),
        Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711)),
    ])

# %% [markdown]
# `x_y_pixel` should be the input resolution.

# %%
x_y_pixel = 288
preprocess = transform(x_y_pixel)
images_list = [img_name for img_name in os.listdir(input_folder) if os.path.splitext(img_name)[1] == ".jpg"]
images_list = images_list[0:1024]
calib_dataset = np.zeros((len(images_list), 3, x_y_pixel, x_y_pixel))

for idx, img_name in enumerate(sorted(images_list)):
    img = Image.open(os.path.join(input_folder, img_name))
    # img = PILToTensor(img)
    img_preproc = preprocess(img)
    img_transposed = np.transpose(img_preproc.numpy(),(1,2,0))
    #input_data = (img_transposed * 255).astype(np.uint8)  # Assuming image is already normalized
    calib_dataset[idx, :, :, :] = img_preproc

np.save(calibFolder / f"calib_set_{model_name}.npy", calib_dataset)

# %% [markdown]
# We will load our parsed HAR from the Parsing Tutorial

# %%
# Second, we will load our parsed HAR from the Parsing Tutorial

hailo_model_har_name = f"{model_name}_hailo_model.har"
hailo_model_har_path = har_path / hailo_model_har_name
assert os.path.isfile(hailo_model_har_path), "Please provide valid path for HAR file"
print(f"Model from {hailo_model_har_path}")
runner = ClientRunner(har=str(hailo_model_har_path),hw_arch=chosen_hw_arch)
# Out:
# Model from hailoDFC/models/Harfiles/Modified_RN50x4_hailo_model.har

# %%
# Batch size is 8 by default
# alls = "normalization1 = normalization([123.675, 116.28, 103.53], [58.395, 57.12, 57.375])\n" # From tutorial

# Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711)), # From Lia
#alls = "normalization1 = normalization([0.48145466, 0.4578275, 0.40821073], [0.26862954, 0.26130258, 0.27577711])\n"

# Load the model script to ClientRunner so it will be considered on optimization
# runner.load_model_script(alls)

# Call Optimize to perform the optimization process
runner.optimize(calib_dataset)

# Save the result state to a Quantized HAR file
quantized_model_har_path = str(har_path / f"{model_name}_quantized_model.har")
runner.save_har(quantized_model_har_path)
print(f"saved model at {quantized_model_har_path}")
# Out:
# [info] Starting Model Optimization
# [warning] Reducing optimization level to 0 (the accuracy won't be optimized and compression won't be used) because there's no available GPU
# [warning] Running model optimization with zero level of optimization is not recommended for production use and might lead to suboptimal accuracy results
# [info] Model received quantization params from the hn
# [info] Starting Mixed Precision
# [info] Mixed Precision is done (completion time is 00:00:00.39)
# [info] LayerNorm Decomposition skipped
# [info] Starting Statistics Collector
# ---------------------------------------------------------------------------
# BadInputsShape                            Traceback (most recent call last)
# Cell In[21], line 11
#       1 # Batch size is 8 by default
#       2 # alls = "normalization1 = normalization([123.675, 116.28, 103.53], [58.395, 57.12, 57.375])\n" # From tutorial
#       3
#    (...)
#       9
#      10 # Call Optimize to perform the optimization process
# ---> 11 runner.optimize(calib_dataset)
#      13 # Save the result state to a Quantized HAR file
#      14 quantized_model_har_path = str(har_path / f"{model_name}_quantized_model.har")
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_sdk_common/states/states.py:16, in allowed_states.<locals>.wrap.<locals>.wrapped_func(self, *args, **kwargs)
#      12 if self._state not in states:
#      13     raise InvalidStateException(
#      14         f"The execution of {func.__name__} is not available under the state: {self._state.value}",
#      15     )
# ---> 16 return func(self, *args, **kwargs)
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_sdk_client/runner/client_runner.py:2093, in ClientRunner.optimize(self, calib_data, data_type, work_dir)
#    2061 @allowed_states(States.HAILO_MODEL, States.FP_OPTIMIZED_MODEL)
#    2062 def optimize(self, calib_data, data_type=CalibrationDataType.auto, work_dir=None):
#    2063     """
#    2064     Apply optimizations to the model:
#    2065
#    (...)
#    2091
#    2092     """
# -> 2093     self._optimize(calib_data, data_type=data_type, work_dir=work_dir)
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_sdk_common/states/states.py:16, in allowed_states.<locals>.wrap.<locals>.wrapped_func(self, *args, **kwargs)
#      12 if self._state not in states:
#      13     raise InvalidStateException(
#      14         f"The execution of {func.__name__} is not available under the state: {self._state.value}",
#      15     )
# ---> 16 return func(self, *args, **kwargs)
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_sdk_client/runner/client_runner.py:1935, in ClientRunner._optimize(self, calib_data, data_type, work_dir)
#    1933 if self._state == States.HAILO_MODEL:
#    1934     self._optimize_full_precision(calib_data=calib_data, data_type=data_type)
# -> 1935 self._sdk_backend.full_quantization(calib_data, data_type=data_type, work_dir=work_dir)
#    1936 self._state = States.QUANTIZED_MODEL
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_sdk_client/sdk_backend/sdk_backend.py:1045, in SDKBackendQuantization.full_quantization(self, data, data_type, work_dir, force_results_by_layer)
#    1043 self.pre_quantization_structural()
#    1044 params_pre_quantization = copy.deepcopy(self.get_params_pre_quantization())
# -> 1045 self._full_acceleras_run(self.calibration_data, data_type)
#    1046 self._logger.verbose("Core and post Quantization is done with Acceleras")
#    1047 self._finalize_quantization()
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_sdk_client/sdk_backend/sdk_backend.py:1229, in SDKBackendQuantization._full_acceleras_run(self, data, data_type)
#    1224     else:
#    1225         # the compression level and the optimization level are not set to the recommended values
#    1226         self._logger.info(
#    1227             f"To obtain best performance for models with number of parameters larger than {self.hw_arch.HAILO15_LARGE_MODEL_PARAMS_TH}, it is recommended to use optimization level and compression level {RECOMMENDED_OPTM_LEVEL}."
#    1228         )
# -> 1229 optimization_flow.run()
#    1230 fp_after_optimization = optimization_flow.get_acceleras_params()
#    1231 self.save_and_load_params_hailo_optimized(fp_after_optimization)
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/tools/orchestator.py:306, in flow_control_method.<locals>.wrapper(self, *args, **kwargs)
#     302             setattr(self, attr_name, method_wrapper(method, sup))
#     304 try:
#     305     # Execute the original run function
# --> 306     return func(self, *args, **kwargs)
#     308 finally:
#     309     # Restore original methods after run execution
#     310     self._call_history = sup.export() if sup.current_checkpoint else None
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/flows/optimization_flow.py:326, in OptimizationFlow.run(self, memento, run_until)
#     324 for ind, step_func in enumerate(step_funcs):
#     325     self._step_index = ind
# --> 326     step_func()
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/tools/orchestator.py:250, in flow_control_method.<locals>.wrapper.<locals>.method_wrapper.<locals>.wrapped(*args, **kwargs)
#     248 if sup.state == SupervisorState.RUNNING:
#     249     with sup.visit_node(method_name):
# --> 250         result = method(*args, **kwargs)
#     251         if method_name == run_until:
#     252             sup.state = SupervisorState.DISABLED
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/tools/subprocess_wrapper.py:124, in subprocess_wrapper.<locals>.decorator.<locals>.parent_wrapper(self, *args, **kwargs)
#     122 self.dist_info = dist_info
#     123 self.build_model()
# --> 124 func(self, *args, **kwargs)
#     126 # This flag should be present in Develop
#     127 if force_rebuild:
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/flows/optimization_flow.py:344, in OptimizationFlow.step1(self)
#     342 self.pre_quantization_structural()
#     343 self._update_fp_data()
# --> 344 self.pre_quantization_optimization()
#     345 self.core_quantization()
#     346 self._update_quantize_data()
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/tools/orchestator.py:250, in flow_control_method.<locals>.wrapper.<locals>.method_wrapper.<locals>.wrapped(*args, **kwargs)
#     248 if sup.state == SupervisorState.RUNNING:
#     249     with sup.visit_node(method_name):
# --> 250         result = method(*args, **kwargs)
#     251         if method_name == run_until:
#     252             sup.state = SupervisorState.DISABLED
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/flows/optimization_flow.py:388, in OptimizationFlow.pre_quantization_optimization(self)
#     386 def pre_quantization_optimization(self):
#     387     self._resolution_reduction()
# --> 388     self._collect_stats()
#     389     self._matmul_correction_removal()
#     390     self._global_avgpool_reduction()
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/tools/orchestator.py:250, in flow_control_method.<locals>.wrapper.<locals>.method_wrapper.<locals>.wrapped(*args, **kwargs)
#     248 if sup.state == SupervisorState.RUNNING:
#     249     with sup.visit_node(method_name):
# --> 250         result = method(*args, **kwargs)
#     251         if method_name == run_until:
#     252             sup.state = SupervisorState.DISABLED
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/flows/optimization_flow.py:463, in OptimizationFlow._collect_stats(self)
#     455 def _collect_stats(self):
#     456     stats_collector = StatsCollector(
#     457         self.model,
#     458         self._parsed_config,
#    (...)
#     461         logger=self._logger,
#     462     )
# --> 463     stats_collector.run()
#     464     self._finalize_algorithm(stats_collector)
#     465     self.save_params(f"{self.model.model_name}_layer_stats.npz", params_type="layer_stats")
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/algorithms/optimization_algorithm.py:50, in OptimizationAlgorithm.run(self)
#      48 def run(self):
#      49     self.finalize_config()
# ---> 50     return super().run()
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/algorithms/algorithm_base.py:145, in AlgorithmBase.run(self, memento)
#     143 self._logger.log(self._logger_level, f"Starting {self._name}")
#     144 self.log_config()
# --> 145 self._setup()
#     146 try:
#     147     if memento is not None and self.CHECKPOINT_POLICY == CheckPointPolicy.SAVE_MID_RUN:
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/algorithms/stats_collection/stats_collection.py:75, in StatsCollector._setup(self)
#      73 self._dataset = self._unbatched_dataset.take(calibset_size).batch(batch_size)
#      74 self._batch_count = calibset_size // batch_size
# ---> 75 self.validate_shapes()
#      76 self._logger.info(f"Using dataset with {calibset_size} entries for calibration")
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/algorithms/stats_collection/stats_collection.py:85, in StatsCollector.validate_shapes(self)
#      83 for key in input_data:
#      84     layer = self._model.layers[key]
# ---> 85     layer.validate_shape(input_data[key])
#
# File ~/Documents/ProjWork1_DFC/hailoDFC/hailodfc/lib/python3.10/site-packages/hailo_model_optimization/acceleras/hailo_layers/hailo_io.py:183, in HailoInputLayer.validate_shape(self, input_data)
#     181         return
#     182 else:
# --> 183     raise BadInputsShape(self.full_name, input_shape, data_shape)
#
# BadInputsShape: Data shape (3, 288, 288) for layer Modified_RN50x4/input_layer1 doesn't match network's input shape (288, 288, 3)

# %% [markdown]
# ## Compile the quantized model
#
# Now we can compile the quantized model

# %%
quantized_model_har_path = str(har_path / f"{model_name}_quantized_model.har")
print(f"Model used:{model_name}_quantized_model.har")
runner = ClientRunner(har=quantized_model_har_path,hw_arch=chosen_hw_arch)
# By default it uses the hw_arch that is saved on the HAR. It is not recommended to change the hw_arch after Optimization.

hef = runner.compile()

file_name = str(hef_path / f"{model_name}.hef")
with open(file_name, "wb") as f:
    f.write(hef)

har_path =ptf.HarPath/ f"{model_name}_compiled_model.har"
runner.save_har(har_path)
# Out:
# Model used:Modified_RN50x4_quantized_model.har
# [info] To achieve optimal performance, set the compiler_optimization_level to "max" by adding performance_param(compiler_optimization_level=max) to the model script. Note that this may increase compilation time.
# [info] Loading network parameters
# [info] Starting Hailo allocation and compilation flow
# [info] Adding collapsed format conversion after const_input1
# [info] Adding collapsed format conversion after const_input1
# [info] Adding collapsed format conversion after conv87
# [info] Finding the best partition to contexts...
# [info] Iteration #1 - Contexts: 5
# [info] Iteration #2 - Contexts: 5
# [info] Iteration #3 - Contexts: 5
# [info] Iteration #4 - Contexts: 5
# [info] Iteration #5 - Contexts: 5
# [info] Iteration #6 - Contexts: 5
# [info] Iteration #7 - Contexts: 5
# [info] Iteration #8 - Contexts: 5
# [info] Iteration #9 - Contexts: 5
# [info] Iteration #10 - Contexts: 5
# [info] Iteration #11 - Contexts: 5
# [info] Iteration #12 - Contexts: 5
# [info] Iteration #13 - Contexts: 5
# [info] Iteration #14 - Contexts: 5
# [info] Iteration #15 - Contexts: 5
# [info] Iteration #16 - Contexts: 5
# [info] Iteration #17 - Contexts: 5
# [info] Iteration #18 - Contexts: 5
# [info] Iteration #19 - Contexts: 5
# [info] Iteration #20 - Contexts: 5
# [info] Iteration #21 - Contexts: 5
# [info] Iteration #22 - Contexts: 5
# [info] Iteration #23 - Contexts: 5
# [info] Iteration #24 - Contexts: 5
# [info] Iteration #25 - Contexts: 5
# [info] Iteration #26 - Contexts: 5
# [info] Iteration #27 - Contexts: 5
# [info] Iteration #28 - Contexts: 5
# [info] Iteration #29 - Contexts: 5
# [info] Iteration #30 - Contexts: 5
# [info] Iteration #31 - Contexts: 5
# [info] Iteration #32 - Contexts: 5
# [info] Iteration #33 - Contexts: 5
# [info] Iteration #34 - Contexts: 5
# [info] Iteration #35 - Contexts: 5
# [info] Iteration #36 - Contexts: 5
# [info] Iteration #37 - Contexts: 5
# [info] Iteration #38 - Contexts: 5
# [info] Iteration #39 - Contexts: 5
# [info] Iteration #40 - Contexts: 5
# [info] Iteration #41 - Contexts: 5
# [info] Iteration #42 - Contexts: 5
# [info] Iteration #43 - Contexts: 5
# [info] Iteration #44 - Contexts: 5
# [info] Iteration #45 - Contexts: 5
# [info] Iteration #46 - Contexts: 5
# [info] Iteration #47 - Contexts: 5
# [info] Iteration #48 - Contexts: 5
# [info] Iteration #49 - Contexts: 5
# [info] Iteration #50 - Contexts: 5
# [info] Iteration #51 - Contexts: 5
# [info] Iteration #52 - Contexts: 5
# [info] Iteration #53 - Contexts: 5
# [info] Iteration #54 - Contexts: 5
# [info] Iteration #55 - Contexts: 5
# [info] Iteration #56 - Contexts: 5
# [info] Iteration #57 - Contexts: 5
# [info] Iteration #58 - Contexts: 5
# [info] Iteration #59 - Contexts: 5
# [info] Iteration #60 - Contexts: 5
# [info] Iteration #61 - Contexts: 5
# [info] Iteration #62 - Contexts: 5
# [info] Iteration #63 - Contexts: 5
# [info] Iteration #64 - Contexts: 5
# [info] Iteration #65 - Contexts: 5
# [info] Iteration #66 - Contexts: 5
# [info] Iteration #67 - Contexts: 5
# [info] Iteration #68 - Contexts: 5
# [info] Iteration #69 - Contexts: 5
# [info] Iteration #70 - Contexts: 5
# [info] Iteration #71 - Contexts: 5
# [info] Iteration #72 - Contexts: 5
# [info] Iteration #73 - Contexts: 5
# [info] Iteration #74 - Contexts: 5
# [info] Iteration #75 - Contexts: 5
# [info] Iteration #76 - Contexts: 5
# [info] Iteration #77 - Contexts: 5
# [info] Iteration #78 - Contexts: 5
# [info] Iteration #79 - Contexts: 5
# [info] Iteration #80 - Contexts: 5
# [info] Iteration #81 - Contexts: 5
# [info] Iteration #82 - Contexts: 5
# [info] Iteration #83 - Contexts: 5
# [info] Iteration #84 - Contexts: 5
# [info] Iteration #85 - Contexts: 5
# [info] Iteration #86 - Contexts: 5
# [info] Iteration #87 - Contexts: 5
# [info] Iteration #88 - Contexts: 5
# [info] Iteration #89 - Contexts: 5
# [info] Iteration #90 - Contexts: 5
# [info] Iteration #91 - Contexts: 5
# [info] Iteration #92 - Contexts: 5
# [info] Iteration #93 - Contexts: 5
# [info] Iteration #94 - Contexts: 5
# [info] Iteration #95 - Contexts: 5
# [info] Iteration #96 - Contexts: 5
# [info] Iteration #97 - Contexts: 5
# [info] Iteration #98 - Contexts: 5
# [info] Iteration #99 - Contexts: 5
# [info] Iteration #100 - Contexts: 5
# [info] Iteration #101 - Contexts: 5
# [info] Iteration #102 - Contexts: 5
# [info] Iteration #103 - Contexts: 5
# [info] Iteration #104 - Contexts: 5
# [info] Iteration #105 - Contexts: 5
# [info] Iteration #106 - Contexts: 5
# [info] Iteration #107 - Contexts: 5
# [info] Iteration #108 - Contexts: 5
# [info] Iteration #109 - Contexts: 5
# [info] Iteration #110 - Contexts: 5
# [info] Iteration #111 - Contexts: 5
# [info] Iteration #112 - Contexts: 5
# [info] Iteration #113 - Contexts: 5
# [info] Iteration #114 - Contexts: 5
# [info] Iteration #115 - Contexts: 5
# [info] Iteration #116 - Contexts: 5
# [info] Iteration #117 - Contexts: 5
# [info] Iteration #118 - Contexts: 5
# [info] Iteration #119 - Contexts: 5
# [info] Iteration #120 - Contexts: 5
# [info] Iteration #121 - Contexts: 5
# [info] Iteration #122 - Contexts: 5
# [info] Iteration #123 - Contexts: 5
# [info] Iteration #124 - Contexts: 5
# [info] Iteration #125 - Contexts: 5
# [info] Iteration #126 - Contexts: 5
# [info] Iteration #127 - Contexts: 5
# [info] Iteration #128 - Contexts: 5
# [info] Iteration #129 - Contexts: 5
# [info] Iteration #130 - Contexts: 5
# [info] Iteration #131 - Contexts: 5
# [info] Iteration #132 - Contexts: 5
# [info] Iteration #133 - Contexts: 5
# [info] Iteration #134 - Contexts: 5
# [info] Iteration #135 - Contexts: 5
# [info] Iteration #136 - Contexts: 5
# [info] Iteration #137 - Contexts: 5
# [info] Iteration #138 - Contexts: 5
# [info] Iteration #139 - Contexts: 5
# [info] Iteration #140 - Contexts: 5
# [info] Iteration #141 - Contexts: 5
# [info] Iteration #142 - Contexts: 5
# [info] Iteration #143 - Contexts: 5
# [info] Iteration #144 - Contexts: 5
# [info] Iteration #145 - Contexts: 5
# [info] Iteration #146 - Contexts: 5
# [info] Iteration #147 - Contexts: 5
# [info] Iteration #148 - Contexts: 5
# [info] Iteration #149 - Contexts: 5
# [info] Iteration #150 - Contexts: 5
# [info] Iteration #151 - Contexts: 5
# [info] Iteration #152 - Contexts: 5
# [info] Iteration #153 - Contexts: 5
# [info] Iteration #154 - Contexts: 6
# [info] Iteration #155 - Contexts: 6
# [info] Iteration #156 - Contexts: 6
# [info] Iteration #157 - Contexts: 6
# [info] Iteration #158 - Contexts: 6
# [info] Iteration #159 - Contexts: 6
# [info] Iteration #160 - Contexts: 6
# [info] Iteration #161 - Contexts: 6
# [info] Iteration #162 - Contexts: 6
# [info] Iteration #163 - Contexts: 6
# [info] Iteration #164 - Contexts: 6
# [info] Iteration #165 - Contexts: 6
# [info] Iteration #166 - Contexts: 6
# [info] Iteration #167 - Contexts: 6
# [info] Iteration #168 - Contexts: 6
# [info] Iteration #169 - Contexts: 6
# [info] Iteration #170 - Contexts: 6
# [info] Iteration #171 - Contexts: 6
# [info] Iteration #172 - Contexts: 6
# [info] Iteration #173 - Contexts: 6
# [info] Iteration #174 - Contexts: 6
# [info] Iteration #175 - Contexts: 6
# [info] Iteration #176 - Contexts: 6
# [info] Iteration #177 - Contexts: 6
# [info] Iteration #178 - Contexts: 6
# [info] Iteration #179 - Contexts: 6
# [info] Iteration #180 - Contexts: 6
# [info] Iteration #181 - Contexts: 6
# [info] Iteration #182 - Contexts: 6
# [info] Iteration #183 - Contexts: 6
# [info] Iteration #184 - Contexts: 6
# [info] Iteration #185 - Contexts: 6
# [info] Iteration #186 - Contexts: 6
# [info] Iteration #187 - Contexts: 6
# [info] Iteration #188 - Contexts: 6
# [info] Iteration #189 - Contexts: 6
# [info] Iteration #190 - Contexts: 6
# [info] Iteration #191 - Contexts: 6
# [info] Iteration #192 - Contexts: 6
# [info] Iteration #193 - Contexts: 6
# [info] Iteration #194 - Contexts: 6
# [info] Iteration #195 - Contexts: 6
# [info] Iteration #196 - Contexts: 6
# [info] Iteration #197 - Contexts: 6
# [info] Iteration #198 - Contexts: 6
# [info] Iteration #199 - Contexts: 6
# [info] Iteration #200 - Contexts: 6
# [info] Iteration #201 - Contexts: 6
# [info] Iteration #202 - Contexts: 6
# [info] Iteration #203 - Contexts: 6
# [info] Iteration #204 - Contexts: 6
# [info] Iteration #205 - Contexts: 6
# [info] Iteration #206 - Contexts: 6
# [info] Iteration #207 - Contexts: 6
# [info] Iteration #208 - Contexts: 6
# [info] Iteration #209 - Contexts: 6
# [info] Iteration #210 - Contexts: 6
# [info] Iteration #211 - Contexts: 6
# [info] Iteration #212 - Contexts: 6
# [info] Iteration #213 - Contexts: 6
# [info] Iteration #214 - Contexts: 6
# [info] Iteration #215 - Contexts: 6
# [info] Iteration #216 - Contexts: 6
# [info] Iteration #217 - Contexts: 6
# [info] Iteration #218 - Contexts: 6
# [info] Iteration #219 - Contexts: 6
# [info] Iteration #220 - Contexts: 6
# [info] Iteration #221 - Contexts: 6
# [info] Iteration #222 - Contexts: 6
# [info] Iteration #223 - Contexts: 6
# [info] Iteration #224 - Contexts: 6
# [info] Iteration #225 - Contexts: 6
# [info] Iteration #226 - Contexts: 6
# [info] Iteration #227 - Contexts: 6
# [info] Iteration #228 - Contexts: 6
# [info] Iteration #229 - Contexts: 6
# [info] Iteration #230 - Contexts: 6
# [info] Iteration #231 - Contexts: 6
# [info] Iteration #232 - Contexts: 6
# [info] Iteration #233 - Contexts: 6
# [info] Iteration #234 - Contexts: 6
# [info] Iteration #235 - Contexts: 6
# [info] Iteration #236 - Contexts: 6
# [info] Iteration #237 - Contexts: 6
# [info] Iteration #238 - Contexts: 6
# [info] Iteration #239 - Contexts: 6
# [info] Iteration #240 - Contexts: 6
# [info] Iteration #241 - Contexts: 6
# [info] Iteration #242 - Contexts: 6
# [info] Iteration #243 - Contexts: 6
# [info] Iteration #244 - Contexts: 6
# [info] Iteration #245 - Contexts: 6
# [info] Iteration #246 - Contexts: 6
# [info] Iteration #247 - Contexts: 6
# [info] Iteration #248 - Contexts: 6
# [info] Iteration #249 - Contexts: 6
# [info] Iteration #250 - Contexts: 6
# [info] Iteration #251 - Contexts: 7
# [info] Iteration #252 - Contexts: 7
# [info] Iteration #253 - Contexts: 7
# [info] Iteration #254 - Contexts: 7
# [info] Iteration #255 - Contexts: 7
# [info] Iteration #256 - Contexts: 7
# [info] Iteration #257 - Contexts: 7
# [info] Iteration #258 - Contexts: 7
# [info] Iteration #259 - Contexts: 7
# [info] Iteration #260 - Contexts: 7
# [info] Iteration #261 - Contexts: 7
# [info] Iteration #262 - Contexts: 7
# [info] Iteration #263 - Contexts: 7
# [info] Iteration #264 - Contexts: 7
# [info] Iteration #265 - Contexts: 7
# [info] Iteration #266 - Contexts: 7
# [info] Iteration #267 - Contexts: 7
# [info] Iteration #268 - Contexts: 7
# [info] Iteration #269 - Contexts: 7
# [info] Iteration #270 - Contexts: 7
# [info] Iteration #271 - Contexts: 7
# [info] Iteration #272 - Contexts: 7
# [info] Iteration #273 - Contexts: 7
# [info] Iteration #274 - Contexts: 7
# [info] Iteration #275 - Contexts: 7
# [info] Iteration #276 - Contexts: 7
# [info] Iteration #277 - Contexts: 7
# [info] Iteration #278 - Contexts: 7
# [info] Iteration #279 - Contexts: 7
# [info] Iteration #280 - Contexts: 7
# [info] Iteration #281 - Contexts: 7
# [info] Iteration #282 - Contexts: 7
# [info] Iteration #283 - Contexts: 7
# [info] Iteration #284 - Contexts: 7
# [info] Iteration #285 - Contexts: 7
# [info] Iteration #286 - Contexts: 7
# [info] Iteration #287 - Contexts: 7
# [info] Iteration #288 - Contexts: 7
# [info] Iteration #289 - Contexts: 7
# [info] Iteration #290 - Contexts: 7
# [info] Iteration #291 - Contexts: 7
# [info] Iteration #292 - Contexts: 7
# [info] Iteration #293 - Contexts: 7
# [info] Iteration #294 - Contexts: 7
# [info] Iteration #295 - Contexts: 7
# [info] Iteration #296 - Contexts: 7
# [info] Iteration #297 - Contexts: 7
# [info] Iteration #298 - Contexts: 7
# [info] Iteration #299 - Contexts: 7
# [info] Iteration #300 - Contexts: 7
# [info] Iteration #301 - Contexts: 7
# [info] Iteration #302 - Contexts: 7
# [info] Iteration #303 - Contexts: 7
# [info] Iteration #304 - Contexts: 7
# [info] Iteration #305 - Contexts: 7
# [info] Iteration #306 - Contexts: 7
# [info] Iteration #307 - Contexts: 7
# [info] Iteration #308 - Contexts: 7
# [info] Iteration #309 - Contexts: 7
# [info] Iteration #310 - Contexts: 7
# [info] Iteration #311 - Contexts: 7
# [info] Iteration #312 - Contexts: 7
# [info] Iteration #313 - Contexts: 7
# [info] Iteration #314 - Contexts: 7
# [info] Iteration #315 - Contexts: 7
# [info] Iteration #316 - Contexts: 7
# [info] Iteration #317 - Contexts: 7
# [info] Iteration #318 - Contexts: 7
# [info] Iteration #319 - Contexts: 7
# [info] Iteration #320 - Contexts: 7
# [info] Iteration #321 - Contexts: 7
# [info] Iteration #322 - Contexts: 7
# [info] Iteration #323 - Contexts: 7
# [info] Iteration #324 - Contexts: 7
# [info] Iteration #325 - Contexts: 7
# [info] Iteration #326 - Contexts: 7
# [info] Iteration #327 - Contexts: 7
# [info] Iteration #328 - Contexts: 7
# [info] Iteration #329 - Contexts: 7
# [info] Iteration #330 - Contexts: 7
# [info] Iteration #331 - Contexts: 7
# [info] Iteration #332 - Contexts: 7
# [info] Iteration #333 - Contexts: 7
# [info] Iteration #334 - Contexts: 7
# [info] Iteration #335 - Contexts: 7
# [info] Iteration #336 - Contexts: 7
# [info] Iteration #337 - Contexts: 7
# [info] Iteration #338 - Contexts: 7
# [info] Iteration #339 - Contexts: 7
# [info] Iteration #340 - Contexts: 7
# [info] Iteration #341 - Contexts: 7
# [info] Iteration #342 - Contexts: 7
# [info] Iteration #343 - Contexts: 7
# [info] Iteration #344 - Contexts: 7
# [info] Iteration #345 - Contexts: 8
# [info] Iteration #346 - Contexts: 8
# [info] Iteration #347 - Contexts: 8
# [info] Iteration #348 - Contexts: 8
# [info] Iteration #349 - Contexts: 8
# [info] Iteration #350 - Contexts: 8
# [info] Iteration #351 - Contexts: 8
# [info] Iteration #352 - Contexts: 8
# [info] Iteration #353 - Contexts: 8
# [info] Iteration #354 - Contexts: 8
# [info] Iteration #355 - Contexts: 8
# [info] Iteration #356 - Contexts: 8
# [info] Iteration #357 - Contexts: 8
# [info] Iteration #358 - Contexts: 8
# [info] Iteration #359 - Contexts: 8
# [info] Iteration #360 - Contexts: 8
# [info] Iteration #361 - Contexts: 8
# [info] Iteration #362 - Contexts: 8
# [info] Iteration #363 - Contexts: 8
# [info] Iteration #364 - Contexts: 8
# [info] Iteration #365 - Contexts: 8
# [info] Iteration #366 - Contexts: 8
# [info] Iteration #367 - Contexts: 8
# [info] Iteration #368 - Contexts: 8
# [info] Iteration #369 - Contexts: 8
# [info] Iteration #370 - Contexts: 8
# [info] Iteration #371 - Contexts: 8
# [info] Iteration #372 - Contexts: 8
# [info] Iteration #373 - Contexts: 8
# [info] Iteration #374 - Contexts: 8
# [info] Iteration #375 - Contexts: 8
# [info] Iteration #376 - Contexts: 8
# [info] Iteration #377 - Contexts: 8
# [info] Iteration #378 - Contexts: 8
# [info] Iteration #379 - Contexts: 8
# [info] Iteration #380 - Contexts: 8
# [info] Iteration #381 - Contexts: 8
# [info] Iteration #382 - Contexts: 8
# [info] Iteration #383 - Contexts: 8
# [info] Iteration #384 - Contexts: 8
# [info] Iteration #385 - Contexts: 8
# [info] Iteration #386 - Contexts: 8
# [info] Iteration #387 - Contexts: 8
# [info] Iteration #388 - Contexts: 8
# [info] Iteration #389 - Contexts: 8
# [info] Iteration #390 - Contexts: 8
# [info] Iteration #391 - Contexts: 8
# [info] Iteration #392 - Contexts: 8
# [info] Iteration #393 - Contexts: 8
# [info] Iteration #394 - Contexts: 8
# [info] Iteration #395 - Contexts: 8
# [info] Iteration #396 - Contexts: 8
# [info] Iteration #397 - Contexts: 8
# [info] Iteration #398 - Contexts: 8
# [info] Iteration #399 - Contexts: 8
# [info] Iteration #400 - Contexts: 8
# [info] Iteration #401 - Contexts: 8
# [info] Iteration #402 - Contexts: 8
# [info] Iteration #403 - Contexts: 8
# [info] Iteration #404 - Contexts: 8
# [info] Iteration #405 - Contexts: 8
# [info] Iteration #406 - Contexts: 8
# [info] Iteration #407 - Contexts: 8
# [info] Iteration #408 - Contexts: 8
# [info] Iteration #409 - Contexts: 8
# [info] Iteration #410 - Contexts: 8
# [info] Iteration #411 - Contexts: 8
# [info] Iteration #412 - Contexts: 8
# [info] Iteration #413 - Contexts: 8
# [info] Iteration #414 - Contexts: 8
# [info] Iteration #415 - Contexts: 8
# [info] Iteration #416 - Contexts: 8
# [info] Iteration #417 - Contexts: 8
# [info] Iteration #418 - Contexts: 8
# [info] Iteration #419 - Contexts: 8
# [info] Iteration #420 - Contexts: 8
# [info] Iteration #421 - Contexts: 8
# [info] Iteration #422 - Contexts: 8
# [info] Iteration #423 - Contexts: 8
# [info] Iteration #424 - Contexts: 8
# [info] Iteration #425 - Contexts: 8
# [info] Iteration #426 - Contexts: 8
# [info] Iteration #427 - Contexts: 8
# [info] Iteration #428 - Contexts: 8
# [info] Iteration #429 - Contexts: 8
# [info] Iteration #430 - Contexts: 8
# [info] Iteration #431 - Contexts: 8
# [info] Iteration #432 - Contexts: 8
# [info] Iteration #433 - Contexts: 8
# [info] Iteration #434 - Contexts: 8
# [info] Iteration #435 - Contexts: 8
# [info] Iteration #436 - Contexts: 9
# [info] Iteration #437 - Contexts: 9
# [info] Iteration #438 - Contexts: 9
# [info] Iteration #439 - Contexts: 9
# [info] Iteration #440 - Contexts: 9
# [info] Iteration #441 - Contexts: 9
# [info] Iteration #442 - Contexts: 9
# [info] Iteration #443 - Contexts: 9
# [info] Iteration #444 - Contexts: 9
# [info] Iteration #445 - Contexts: 9
# [info] Iteration #446 - Contexts: 9
# [info] Iteration #447 - Contexts: 9
# [info] Iteration #448 - Contexts: 9
# [info] Iteration #449 - Contexts: 9
# [info] Iteration #450 - Contexts: 9
# [info] Iteration #451 - Contexts: 9
# [info] Iteration #452 - Contexts: 9
# [info] Iteration #453 - Contexts: 9
# [info] Iteration #454 - Contexts: 9
# [info] Iteration #455 - Contexts: 9
# [info] Iteration #456 - Contexts: 9
# [info] Iteration #457 - Contexts: 9
# [info] Iteration #458 - Contexts: 9
# [info] Iteration #459 - Contexts: 9
# [info] Iteration #460 - Contexts: 9
# [info] Iteration #461 - Contexts: 9
# [info] Iteration #462 - Contexts: 9
# [info] Iteration #463 - Contexts: 9
# [info] Iteration #464 - Contexts: 9
# [info] Iteration #465 - Contexts: 9
# [info] Iteration #466 - Contexts: 9
# [info] Iteration #467 - Contexts: 9
# [info] Iteration #468 - Contexts: 9
# [info] Iteration #469 - Contexts: 9
# [info] Iteration #470 - Contexts: 9
# [info] Iteration #471 - Contexts: 9
# [info] Iteration #472 - Contexts: 9
# [info] Iteration #473 - Contexts: 9
# [info] Iteration #474 - Contexts: 9
# [info] Iteration #475 - Contexts: 9
# [info] Iteration #476 - Contexts: 9
# [info] Iteration #477 - Contexts: 9
# [info] Iteration #478 - Contexts: 9
# [info] Iteration #479 - Contexts: 9
# [info] Iteration #480 - Contexts: 9
# [info] Iteration #481 - Contexts: 9
# [info] Iteration #482 - Contexts: 9
# [info] Iteration #483 - Contexts: 9
# [info] Iteration #484 - Contexts: 9
# [info] Iteration #485 - Contexts: 9
# [info] Iteration #486 - Contexts: 9
# [info] Iteration #487 - Contexts: 9
# [info] Iteration #488 - Contexts: 9
# [info] Iteration #489 - Contexts: 9
# [info] Iteration #490 - Contexts: 9
# [info] Iteration #491 - Contexts: 9
# [info] Iteration #492 - Contexts: 9
# [info] Iteration #493 - Contexts: 9
# [info] Iteration #494 - Contexts: 9
# [info] Iteration #495 - Contexts: 9
# [info] Iteration #496 - Contexts: 9
# [info] Iteration #497 - Contexts: 9
# [info] Iteration #498 - Contexts: 9
# [info] Iteration #499 - Contexts: 9
# [info] Iteration #500 - Contexts: 9
# [info] Iteration #501 - Contexts: 9
# [info] Iteration #502 - Contexts: 9
# [info] Iteration #503 - Contexts: 9
# [info] Iteration #504 - Contexts: 9
# [info] Iteration #505 - Contexts: 9
# [info] Iteration #506 - Contexts: 9
# [info] Iteration #507 - Contexts: 9
# [info] Iteration #508 - Contexts: 9
# [info] Iteration #509 - Contexts: 9
# [info] Iteration #510 - Contexts: 9
# [info] Iteration #511 - Contexts: 9
# [info] Iteration #512 - Contexts: 9
# [info] Iteration #513 - Contexts: 9
# [info] Iteration #514 - Contexts: 9
# [info] Iteration #515 - Contexts: 9
# [info] Iteration #516 - Contexts: 9
# [info] Iteration #517 - Contexts: 9
# [info] Iteration #518 - Contexts: 9
# [info] Iteration #519 - Contexts: 9
# [info] Iteration #520 - Contexts: 9
# [info] Iteration #521 - Contexts: 9
# [info] Iteration #522 - Contexts: 9
# [info] Iteration #523 - Contexts: 9
# [info] Iteration #524 - Contexts: 10
# [info] Iteration #525 - Contexts: 10
# [info] Iteration #526 - Contexts: 10
# [info] Iteration #527 - Contexts: 10
# [info] Iteration #528 - Contexts: 10
# [info] Iteration #529 - Contexts: 10
# [info] Iteration #530 - Contexts: 10
# [info] Iteration #531 - Contexts: 10
# [info] Iteration #532 - Contexts: 10
# [info] Iteration #533 - Contexts: 10
# [info] Iteration #534 - Contexts: 10
# [info] Iteration #535 - Contexts: 10
# [info] Iteration #536 - Contexts: 10
# [info] Iteration #537 - Contexts: 10
# [info] Iteration #538 - Contexts: 10
# [info] Iteration #539 - Contexts: 10
# [info] Iteration #540 - Contexts: 10
# [info] Iteration #541 - Contexts: 10
# [info] Iteration #542 - Contexts: 10
# [info] Iteration #543 - Contexts: 10
# [info] Iteration #544 - Contexts: 10
# [info] Iteration #545 - Contexts: 10
# [info] Iteration #546 - Contexts: 10
# [info] Iteration #547 - Contexts: 10
# [info] Iteration #548 - Contexts: 10
# [info] Iteration #549 - Contexts: 10
# [info] Iteration #550 - Contexts: 10
# [info] Iteration #551 - Contexts: 10
# [info] Iteration #552 - Contexts: 10
# [info] Iteration #553 - Contexts: 10
# [info] Iteration #554 - Contexts: 10
# [info] Iteration #555 - Contexts: 10
# [info] Iteration #556 - Contexts: 10
# [info] Iteration #557 - Contexts: 10
# [info] Iteration #558 - Contexts: 10
# [info] Iteration #559 - Contexts: 10
# [info] Iteration #560 - Contexts: 10
# [info] Iteration #561 - Contexts: 10
# [info] Iteration #562 - Contexts: 10
# [info] Iteration #563 - Contexts: 10
# [info] Iteration #564 - Contexts: 10
# [info] Iteration #565 - Contexts: 10
# [info] Iteration #566 - Contexts: 10
# [info] Iteration #567 - Contexts: 10
# [info] Iteration #568 - Contexts: 10
# [info] Iteration #569 - Contexts: 10
# [info] Iteration #570 - Contexts: 10
# [info] Iteration #571 - Contexts: 10
# [info] Iteration #572 - Contexts: 10
# [info] Iteration #573 - Contexts: 10
# [info] Iteration #574 - Contexts: 10
# [info] Iteration #575 - Contexts: 10
# [info] Iteration #576 - Contexts: 10
# [info] Iteration #577 - Contexts: 10
# [info] Iteration #578 - Contexts: 10
# [info] Iteration #579 - Contexts: 10
# [info] Iteration #580 - Contexts: 10
# [info] Iteration #581 - Contexts: 10
# [info] Iteration #582 - Contexts: 10
# [info] Iteration #583 - Contexts: 10
# [info] Iteration #584 - Contexts: 10
# [info] Iteration #585 - Contexts: 10
# [info] Iteration #586 - Contexts: 10
# [info] Iteration #587 - Contexts: 10
# [info] Iteration #588 - Contexts: 10
# [info] Iteration #589 - Contexts: 10
# [info] Iteration #590 - Contexts: 10
# [info] Iteration #591 - Contexts: 10
# [info] Iteration #592 - Contexts: 10
# [info] Iteration #593 - Contexts: 10
# [info] Iteration #594 - Contexts: 10
# [info] Iteration #595 - Contexts: 10
# [info] Iteration #596 - Contexts: 10
# [info] Iteration #597 - Contexts: 10
# [info] Iteration #598 - Contexts: 10
# [info] Iteration #599 - Contexts: 10
# [info] Iteration #600 - Contexts: 10
# [info] Iteration #601 - Contexts: 10
# [info] Iteration #602 - Contexts: 10
# [info] Iteration #603 - Contexts: 10
# [info] Iteration #604 - Contexts: 10
# [info] Iteration #605 - Contexts: 10
# [info] Iteration #606 - Contexts: 10
# [info] Iteration #607 - Contexts: 10
# [info] Iteration #608 - Contexts: 10
# [info] Iteration #609 - Contexts: 11
# [info] Iteration #610 - Contexts: 11
# [info] Iteration #611 - Contexts: 11
# [info] Iteration #612 - Contexts: 11
# [info] Iteration #613 - Contexts: 11
# [info] Iteration #614 - Contexts: 11
# [info] Iteration #615 - Contexts: 11
# [info] Iteration #616 - Contexts: 11
# [info] Iteration #617 - Contexts: 11
# [info] Iteration #618 - Contexts: 11
# [info] Iteration #619 - Contexts: 11
# [info] Iteration #620 - Contexts: 11
# [info] Iteration #621 - Contexts: 11
# [info] Iteration #622 - Contexts: 11
# [info] Iteration #623 - Contexts: 11
# [info] Iteration #624 - Contexts: 11
# [info] Iteration #625 - Contexts: 11
# [info] Iteration #626 - Contexts: 11
# [info] Iteration #627 - Contexts: 11
# [info] Iteration #628 - Contexts: 11
# [info] Iteration #629 - Contexts: 11
# [info] Iteration #630 - Contexts: 11
# [info] Iteration #631 - Contexts: 11
# [info] Iteration #632 - Contexts: 11
# [info] Iteration #633 - Contexts: 11
# [info] Iteration #634 - Contexts: 11
# [info] Iteration #635 - Contexts: 11
# [info] Iteration #636 - Contexts: 11
# [info] Iteration #637 - Contexts: 11
# [info] Iteration #638 - Contexts: 11
# [info] Iteration #639 - Contexts: 11
# [info] Iteration #640 - Contexts: 11
# [info] Iteration #641 - Contexts: 11
# [info] Iteration #642 - Contexts: 11
# [info] Iteration #643 - Contexts: 11
# [info] Iteration #644 - Contexts: 11
# [info] Iteration #645 - Contexts: 11
# [info] Iteration #646 - Contexts: 11
# [info] Iteration #647 - Contexts: 11
# [info] Iteration #648 - Contexts: 11
# [info] Iteration #649 - Contexts: 11
# [info] Iteration #650 - Contexts: 11
# [info] Iteration #651 - Contexts: 11
# [info] Iteration #652 - Contexts: 11
# [info] Iteration #653 - Contexts: 11
# [info] Iteration #654 - Contexts: 11
# [info] Iteration #655 - Contexts: 11
# [info] Iteration #656 - Contexts: 11
# [info] Iteration #657 - Contexts: 11
# [info] Iteration #658 - Contexts: 11
# [info] Iteration #659 - Contexts: 11
# [info] Iteration #660 - Contexts: 11
# [info] Iteration #661 - Contexts: 11
# [info] Iteration #662 - Contexts: 11
# [info] Iteration #663 - Contexts: 11
# [info] Iteration #664 - Contexts: 11
# [info] Iteration #665 - Contexts: 11
# [info] Iteration #666 - Contexts: 11
# [info] Iteration #667 - Contexts: 11
# [info] Iteration #668 - Contexts: 11
# [info] Iteration #669 - Contexts: 11
# [info] Iteration #670 - Contexts: 11
# [info] Iteration #671 - Contexts: 11
# [info] Iteration #672 - Contexts: 11
# [info] Iteration #673 - Contexts: 11
# [info] Iteration #674 - Contexts: 11
# [info] Iteration #675 - Contexts: 11
# [info] Iteration #676 - Contexts: 11
# [info] Iteration #677 - Contexts: 11
# [info] Iteration #678 - Contexts: 11
# [info] Iteration #679 - Contexts: 12
# [info] Iteration #680 - Contexts: 12
# [info] Iteration #681 - Contexts: 12
# [info] Iteration #682 - Contexts: 12
# [info] Iteration #683 - Contexts: 12
# [info] Iteration #684 - Contexts: 12
# [info] Iteration #685 - Contexts: 12
# [info] Iteration #686 - Contexts: 12
# [info] Iteration #687 - Contexts: 12
# [info] Iteration #688 - Contexts: 12
# [info] Iteration #689 - Contexts: 12
# [info] Iteration #690 - Contexts: 12
# [info] Iteration #691 - Contexts: 12
# [info] Iteration #692 - Contexts: 12
# [info] Iteration #693 - Contexts: 12
# [info] Iteration #694 - Contexts: 12
# [info] Iteration #695 - Contexts: 12
# [info] Iteration #696 - Contexts: 12
# [info] Iteration #697 - Contexts: 12
# [info] Iteration #698 - Contexts: 12
# [info] Iteration #699 - Contexts: 12
# [info] Iteration #700 - Contexts: 12
# [info] Iteration #701 - Contexts: 12
# [info] Iteration #702 - Contexts: 12
# [info] Iteration #703 - Contexts: 12
# [info] Iteration #704 - Contexts: 12
# [info] Iteration #705 - Contexts: 12
# [info] Iteration #706 - Contexts: 12
# [info] Iteration #707 - Contexts: 12
# [info] Iteration #708 - Contexts: 12
# [info] Iteration #709 - Contexts: 12
# [info] Iteration #710 - Contexts: 12
# [info] Iteration #711 - Contexts: 12
# [info] Iteration #712 - Contexts: 12
# [info] Iteration #713 - Contexts: 12
# [info] Iteration #714 - Contexts: 12
# [info] Iteration #715 - Contexts: 12
# [info] Iteration #716 - Contexts: 12
# [info] Iteration #717 - Contexts: 12
# [info] Iteration #718 - Contexts: 12
# [info] Iteration #719 - Contexts: 12
# [info] Iteration #720 - Contexts: 12
# [info] Iteration #721 - Contexts: 12
# [info] Iteration #722 - Contexts: 12
# [info] Iteration #723 - Contexts: 12
# [info] Iteration #724 - Contexts: 12
# [info] Iteration #725 - Contexts: 12
# [info] Iteration #726 - Contexts: 12
# [info] Iteration #727 - Contexts: 12
# [info] Iteration #728 - Contexts: 13
# [info] Iteration #729 - Contexts: 13
# [info] Iteration #730 - Contexts: 13
# [info] Iteration #731 - Contexts: 13
# [info] Iteration #732 - Contexts: 13
# [info] Iteration #733 - Contexts: 13
# [info] Iteration #734 - Contexts: 13
# [info] Iteration #735 - Contexts: 13
# [info] Iteration #736 - Contexts: 13
# [info] Iteration #737 - Contexts: 13
# [info] Iteration #738 - Contexts: 13
# [info] Iteration #739 - Contexts: 13
# [info] Iteration #740 - Contexts: 13
# [info] Iteration #741 - Contexts: 13
# [info] Iteration #742 - Contexts: 13
# [info] Iteration #743 - Contexts: 13
# [info] Iteration #744 - Contexts: 13
# [info] Iteration #745 - Contexts: 13
# [info] Iteration #746 - Contexts: 13
# [info] Iteration #747 - Contexts: 13
# [info] Iteration #748 - Contexts: 13
# [info] Iteration #749 - Contexts: 13
# [info] Iteration #750 - Contexts: 13
# [info] Iteration #751 - Contexts: 13
# [info] Iteration #752 - Contexts: 13
# [info] Iteration #753 - Contexts: 13
# [info] Iteration #754 - Contexts: 13
# [info] Iteration #755 - Contexts: 13
# [info] Iteration #756 - Contexts: 13
# [info] Iteration #757 - Contexts: 13
# [info] Iteration #758 - Contexts: 13
# [info] Iteration #759 - Contexts: 13
# [info] Iteration #760 - Contexts: 13
# [info] Iteration #761 - Contexts: 13
# [info] Iteration #762 - Contexts: 13
# [info] Iteration #763 - Contexts: 13
# [info] Iteration #764 - Contexts: 13
# [info] Iteration #765 - Contexts: 13
# [info] Iteration #766 - Contexts: 13
# [info] Iteration #767 - Contexts: 13
# [info] Iteration #768 - Contexts: 13
# [info] Iteration #769 - Contexts: 13
# [info] Iteration #770 - Contexts: 13
# [info] Iteration #771 - Contexts: 14
# [info] Iteration #772 - Contexts: 14
# [info] Iteration #773 - Contexts: 14
# [info] Iteration #774 - Contexts: 14
# [info] Iteration #775 - Contexts: 14
# [info] Iteration #776 - Contexts: 14
# [info] Iteration #777 - Contexts: 14
# [info] Iteration #778 - Contexts: 14
# [info] Iteration #779 - Contexts: 14
# [info] Iteration #780 - Contexts: 14
# [info] Iteration #781 - Contexts: 14
# [info] Iteration #782 - Contexts: 14
# [info] Iteration #783 - Contexts: 14
# [info] Iteration #784 - Contexts: 14
# [info] Iteration #785 - Contexts: 14
# [info] Iteration #786 - Contexts: 14
# [info] Iteration #787 - Contexts: 14
# [info] Iteration #788 - Contexts: 14
# [info] Iteration #789 - Contexts: 14
# [info] Iteration #790 - Contexts: 14
# [info] Iteration #791 - Contexts: 14
# [info] Iteration #792 - Contexts: 14
# [info] Iteration #793 - Contexts: 14
# [info] Iteration #794 - Contexts: 14
# [info] Iteration #795 - Contexts: 14
# [info] Iteration #796 - Contexts: 14
# [info] Iteration #797 - Contexts: 15
# [info] Iteration #798 - Contexts: 15
# [info] Iteration #799 - Contexts: 15
# [info] Iteration #800 - Contexts: 15
# [info] Iteration #801 - Contexts: 15
# [info] Iteration #802 - Contexts: 15
# [info] Iteration #803 - Contexts: 15
# [info] Iteration #804 - Contexts: 15
# [info] Iteration #805 - Contexts: 15
# [info] Iteration #806 - Contexts: 15
# [info] Iteration #807 - Contexts: 15
# [info] Iteration #808 - Contexts: 15
# [info] Iteration #809 - Contexts: 15
# [info] Iteration #810 - Contexts: 15
# [info] Iteration #811 - Contexts: 15
# [info] Iteration #812 - Contexts: 15
# [info] Iteration #813 - Contexts: 15
# [info] Iteration #814 - Contexts: 15
# [info] Iteration #815 - Contexts: 15
# [info] Iteration #816 - Contexts: 15
# [info] Iteration #817 - Contexts: 15
# [info] Iteration #818 - Contexts: 15
# [info] Iteration #819 - Contexts: 15
# [info] Iteration #820 - Contexts: 15
# [info] Iteration #821 - Contexts: 15
# [info] Iteration #822 - Contexts: 15
# [info] Iteration #823 - Contexts: 15
# [info] Iteration #824 - Contexts: 15
# [info] Iteration #825 - Contexts: 15
# [info] Iteration #826 - Contexts: 15
# [info] Iteration #827 - Contexts: 15
# [info] Iteration #828 - Contexts: 15
# [info] Iteration #829 - Contexts: 15
# [info] Iteration #830 - Contexts: 15
# [info] Iteration #831 - Contexts: 15
# [info] Iteration #832 - Contexts: 15
# [info] Iteration #833 - Contexts: 15
# [info] Iteration #834 - Contexts: 15
# [info] Iteration #835 - Contexts: 15
# [info] Iteration #836 - Contexts: 15
# [info] Iteration #837 - Contexts: 15
# [info] Iteration #838 - Contexts: 15
# [info] Iteration #839 - Contexts: 15
# [info] Iteration #840 - Contexts: 15
# [info] Iteration #841 - Contexts: 15
# [info] Iteration #842 - Contexts: 15
# [info] Iteration #843 - Contexts: 15
# [info] Iteration #844 - Contexts: 15
# [info] Iteration #845 - Contexts: 15
# [info] Iteration #846 - Contexts: 15
# [info] Iteration #847 - Contexts: 15
# [info] Iteration #848 - Contexts: 15
# [info] Iteration #849 - Contexts: 15
# [info] Iteration #850 - Contexts: 15
# [info] Iteration #851 - Contexts: 15
# [info] Iteration #852 - Contexts: 15
# [info] Iteration #853 - Contexts: 15
# [info] Iteration #854 - Contexts: 15
# [info] Iteration #855 - Contexts: 15
# [info] Iteration #856 - Contexts: 15
# [info] Iteration #857 - Contexts: 15
# [info] Iteration #858 - Contexts: 15
# [info] Iteration #859 - Contexts: 15
# [info] Iteration #860 - Contexts: 15
# [info] Iteration #861 - Contexts: 15
# [info] Iteration #862 - Contexts: 15
# [info] Iteration #863 - Contexts: 15
# [info] Iteration #864 - Contexts: 15
# [info] Iteration #865 - Contexts: 15
# [info] Iteration #866 - Contexts: 15
# [info] Iteration #867 - Contexts: 15
# [info] Iteration #868 - Contexts: 15
# [info] Iteration #869 - Contexts: 15
# [info] Iteration #870 - Contexts: 15
# [info] Iteration #871 - Contexts: 15
# [info] Iteration #872 - Contexts: 15
#
# [info] Using Multi-context flow
# [info] Resources optimization guidelines: Strategy -> GREEDY Objective -> MAX_FPS
# [info] Resources optimization params: max_control_utilization=60%, max_compute_utilization=60%, max_compute_16bit_utilization=60%, max_memory_utilization (weights)=60%, max_input_aligner_utilization=60%, max_apu_utilization=60%
# [info] input_layer1: Pass
# [info] conv14: Pass
# [info] conv1: Pass
# [info] conv8: Pass
# [info] conv11: Pass
# [info] conv5: Pass
# [info] conv9: Pass
# [info] conv23: Pass
# [info] avgpool1: Pass
# [info] conv22: Pass
# [info] avgpool2: Pass
# [info] conv20: Pass
# [info] conv2: Pass
# [info] avgpool3: Pass
# [info] conv21: Pass
# [info] conv13: Pass
# [info] conv4: Pass
# [info] conv24: Pass
# [info] conv12: Pass
# [info] conv17: Pass
# [info] conv6: Pass
# [info] conv15: Pass
# [info] conv18: Pass
# [info] conv10: Pass
# [info] conv16: Pass
# [info] conv19_d0: Pass
# [info] context_0_to_context_1_0: Pass
# [info] conv26: Pass
# [info] auto_reshape_from_input_layer1_to_conv1: Pass
# [info] conv27: Pass
# [info] conv7_dc: Pass
# [info] conv19_d2: Pass
# [info] conv28: Pass
# [info] conv29: Pass
# [info] conv19_dc: Pass
# [info] conv3_dc: Pass
# [info] conv19_d1: Pass
# [info] conv25: Pass
# [info] conv3_d0: Pass
# [info] conv3_d1: Pass
# [info] conv7_d0: Pass
# [info] conv7_d1: Pass
# [info] sh_from_conv36_to_conv38_d0-3: Pass
# [info] avgpool5: Pass
# [info] conv32: Pass
# [info] conv43: Pass
# [info] conv40: Pass
# [info] conv34: Pass
# [info] conv36: Pass
# [info] avgpool4: Pass
# [info] conv38_dc: Pass
# [info] concat_from_conv38_d0-2_to_conv38_dc: Pass
# [info] context_1_to_context_2_3: Pass
# [info] mux_conv86_d8-9_conv86_d11_to_concat_from_conv86_d6-8_to_conv86_dc_concat_from_conv86_d9-11_to_conv86_dc_extens: Pass
# [info] conv87_d4: Pass
# [info] mux_conv86_d10_conv87_d4_to_concat_from_conv86_d9-11_to_conv86_dc_concat_from_conv87_d3-5_to_conv87_dc: Pass
# [info] conv87_d5: Pass
# [info] conv87_d3: Pass
# [info] conv87_d9: Pass
# [info] conv87_d0: Pass
# [info] conv86_d9: Pass
# [info] conv86_d10: Pass
# [info] conv86_d11: Pass
# [info] conv86_d8: Pass
# [info] conv87_d10: Pass
# [info] mux_conv87_d8-10_to_concat_from_conv87_d6-8_to_conv87_dc_concat_from_conv87_d9-11_to_conv87_dc_extension-shortc: Pass
# [info] mux_conv87_d0-1_conv87_d3_to_concat_from_conv87_d0-2_to_conv87_dc_extension-shortcut_from_context_11_to_context: Pass
# [info] conv87_d11_d7: Pass
# [info] conv87_d11_d3: Pass
# [info] conv87_d11_d4: Pass
# [info] conv87_d11_d0: Pass
# [info] conv87_d11_d6: Pass
# [info] conv87_d11_d9: Pass
# [info] conv87_d11_d1: Pass
# [info] conv87_d11_d11: Pass
# [info] conv87_d11_d8: Pass
# [info] conv87_d11_d5: Pass
# [info] conv87_d11_d2: Pass
# [info] conv87_d11_d10: Pass
# [info] conv88_d5: Pass
# [info] sh_from_sh_from_ew_add27_to_conv87_d8-11_to_conv87_d11_d4_conv87_d11_d5_conv87_d11_d6_conv87_d11_d7: Pass
# [info] conv87_d11_dc: Pass
# [info] concat_from_conv87_d11_d9_conv87_d11_d10_conv87_d11_d11_to_conv87_d11_dc: Pass
# [info] conv87_d11_d13: Pass
# [info] conv88_d6: Pass
# [info] conv88_d2: Pass
# [info] conv88_d3: Pass
# [info] sh_from_sh_from_ew_add27_to_conv87_d8-11_to_conv87_d11_d8_conv87_d11_d9_conv87_d11_d10_conv87_d11_d11: Pass
# [info] concat_from_conv87_d11_d6_conv87_d11_d7_conv87_d11_d8_to_conv87_d11_dc: Pass
# [info] conv88_d7: Pass
# [info] conv88_d8: Pass
# [info] conv88_d0: Pass
# [info] conv88_d9: Pass
# [info] conv88_d10: Pass
# [info] conv88_d1: Pass
# [info] conv87_d11_d12: Pass
# ...
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_9 (context_9):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_10 (context_10):
# Iterations: 4
# Reverts on cluster mapping: 1
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_11 (context_11):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_12 (context_12):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_13 (context_13):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_14 (context_14):
# Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] context_0 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 43.8%               | 32.8%               | 36.7%              |
# [info] | cluster_1 | 50%                 | 68.8%               | 64.1%              |
# [info] | cluster_4 | 75%                 | 76.6%               | 71.9%              |
# [info] | cluster_5 | 75%                 | 59.4%               | 58.6%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 60.9%               | 59.4%               | 57.8%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_1 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 43.8%               | 40.6%               | 41.4%              |
# [info] | cluster_1 | 56.3%               | 75%                 | 95.3%              |
# [info] | cluster_4 | 56.3%               | 93.8%               | 93.8%              |
# [info] | cluster_5 | 31.3%               | 31.3%               | 50%                |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 46.9%               | 60.2%               | 70.1%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_2 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 50%                 | 53.1%               | 90.6%              |
# [info] | cluster_1 | 43.8%               | 57.8%               | 90.6%              |
# [info] | cluster_4 | 37.5%               | 53.1%               | 85.9%              |
# [info] | cluster_5 | 18.8%               | 20.3%               | 35.2%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 37.5%               | 46.1%               | 75.6%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_3 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 75%                 | 81.3%               | 92.2%              |
# [info] | cluster_1 | 43.8%               | 57.8%               | 69.5%              |
# [info] | cluster_4 | 62.5%               | 56.3%               | 92.2%              |
# [info] | cluster_5 | 12.5%               | 9.4%                | 28.1%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 48.4%               | 51.2%               | 70.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_4 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 43.8%               | 31.3%               | 50.8%              |
# [info] | cluster_1 | 37.5%               | 50%                 | 96.9%              |
# [info] | cluster_4 | 56.3%               | 57.8%               | 78.1%              |
# [info] | cluster_5 | 25%                 | 48.4%               | 71.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 40.6%               | 46.9%               | 74.4%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_5 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 25%                 | 15.6%               | 30.5%              |
# [info] | cluster_1 | 31.3%               | 50%                 | 89.1%              |
# [info] | cluster_4 | 68.8%               | 45.3%               | 93%                |
# [info] | cluster_5 | 43.8%               | 39.1%               | 80.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 42.2%               | 37.5%               | 73.2%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_6 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 25%                 | 15.6%               | 30.5%              |
# [info] | cluster_1 | 31.3%               | 50%                 | 89.1%              |
# [info] | cluster_4 | 68.8%               | 45.3%               | 93%                |
# [info] | cluster_5 | 43.8%               | 39.1%               | 80.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 42.2%               | 37.5%               | 73.2%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_7 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 25%                 | 15.6%               | 30.5%              |
# [info] | cluster_1 | 31.3%               | 50%                 | 89.1%              |
# [info] | cluster_4 | 68.8%               | 45.3%               | 93%                |
# [info] | cluster_5 | 43.8%               | 39.1%               | 80.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 42.2%               | 37.5%               | 73.2%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_8 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 25%                 | 15.6%               | 30.5%              |
# [info] | cluster_1 | 31.3%               | 50%                 | 89.1%              |
# [info] | cluster_4 | 68.8%               | 45.3%               | 93%                |
# [info] | cluster_5 | 43.8%               | 39.1%               | 80.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 42.2%               | 37.5%               | 73.2%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_9 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 25%                 | 25%                 | 82.8%              |
# [info] | cluster_4 | 31.3%               | 26.6%               | 79.7%              |
# [info] | cluster_5 | 93.8%               | 29.7%               | 60.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 37.5%               | 20.3%               | 55.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_10 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 37.5%               | 9.4%                | 15.6%              |
# [info] | cluster_1 | 62.5%               | 81.3%               | 96.9%              |
# [info] | cluster_4 | 56.3%               | 42.2%               | 53.9%              |
# [info] | cluster_5 | 100%                | 62.5%               | 80.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 64.1%               | 48.8%               | 61.7%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_11 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 37.5%               | 21.9%               | 71.1%              |
# [info] | cluster_1 | 43.8%               | 26.6%               | 86.7%              |
# [info] | cluster_4 | 18.8%               | 12.5%               | 36.7%              |
# [info] | cluster_5 | 37.5%               | 25%                 | 83.6%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 34.4%               | 21.5%               | 69.5%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_12 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 50%                 | 26.6%               | 74.2%              |
# [info] | cluster_1 | 93.8%               | 39.1%               | 57.8%              |
# [info] | cluster_4 | 43.8%               | 25%                 | 71.1%              |
# [info] | cluster_5 | 75%                 | 31.3%               | 60.9%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 65.6%               | 30.5%               | 66%                |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_13 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 93.8%               | 23.4%               | 25.8%              |
# [info] | cluster_1 | 87.5%               | 25%                 | 37.5%              |
# [info] | cluster_4 | 56.3%               | 15.6%               | 30.5%              |
# [info] | cluster_5 | 87.5%               | 21.9%               | 25%                |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 81.3%               | 21.5%               | 29.7%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] context_14 utilization:
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 12.5%               | 3.1%                | 3.9%               |
# [info] | cluster_1 | 6.3%                | 1.6%                | 2.3%               |
# [info] | cluster_4 | 6.3%                | 12.5%               | 14.1%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 6.3%                | 4.3%                | 5.1%               |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] Successful Mapping (allocation time: 39m 39s)
# [info] Compiling context_0...
# [info] Compiling context_1...
# [info] Compiling context_2...
# [info] Compiling context_3...
# [info] Compiling context_4...
# [info] Compiling context_5...
# [info] Compiling context_6...
# [info] Compiling context_7...
# [info] Compiling context_8...
# [info] Compiling context_9...
# [info] Compiling context_10...
# [info] Compiling context_11...
# [info] Compiling context_12...
# [info] Compiling context_13...
# [info] Compiling context_14...
# [info] Bandwidth of model inputs: 1.89844 Mbps, outputs: 0.0195312 Mbps (for a single frame)
# [info] Bandwidth of DDR buffers: 0.0 Mbps (for a single frame)
# [info] Bandwidth of inter context tensors: 99.7065 Mbps (for a single frame)
# [info] Compiling context_0...
# [info] Compiling context_1...
# [info] Compiling context_2...
# [info] Compiling context_3...
# [info] Compiling context_4...
# [info] Compiling context_5...
# [info] Compiling context_6...
# [info] Compiling context_7...
# [info] Compiling context_8...
# [info] Compiling context_9...
# [info] Compiling context_10...
# [info] Compiling context_11...
# [info] Compiling context_12...
# [info] Compiling context_13...
# [info] Compiling context_14...
# [info] Bandwidth of model inputs: 1.89844 Mbps, outputs: 0.0195312 Mbps (for a single frame)
# [info] Bandwidth of DDR buffers: 0.0 Mbps (for a single frame)
# [info] Bandwidth of inter context tensors: 99.7065 Mbps (for a single frame)
# [info] Building HEF...
# [info] Successful Compilation (compilation time: 1m 9s)
# [info] Saved HAR to: /home/lukasschoepf/Documents/ProjWork1_DFC/hailoDFC/models/Harfiles/Modified_RN50x4_compiled_model.har
